# %%
import pandas as pd

# %%
final = pd.read_csv('final.csv')

# %%
df = pd.read_csv('websheet15.csv')

# %%
final
# Out:
#                                                   Names  \
# 0     Sunflower, Mexican Sunflower (Tithonia rotundi...
# 1                  Sunflower, Procut Horizon Pollenless
# 2                               Sunflower, Procut Peach
# 3        Sunflower, Procut Red Lemon BiColor Pollenless
# 4                    Sunflower, Autumn Beauty (90 days)
# ...                                                 ...
# 9155                 Endless Bouquets Cut Flower Garden
# 9156              Flower Power For Nature's Pollinators
# 9157  Heirloom Rainbow Flowers Colorful, Carefree Zi...
# 9158  Heirloom Summer Garden Dancing, Joyous Sunflowers
# 9159         Protect & Fertilize Green Cover Crop Blend
#
#                                             Description  \
# 0     \n\t\t\t\t\n\tDescription\n\nMexican Sunflower...
# 1     \n\t\t\t\t\n\tDescription\n\nA brand new ProCu...
# 2     \n\t\t\t\t\n\tDescription\n\nStunning, Peach-c...
# 3     \n\t\t\t\t\n\tDescription\n\nBicolor flowers o...
# ...

# %%
df = df[['Names', 'url', 'Description']]

# %%
combined_df = pd.concat([final, df], ignore_index=True)

# %%
combined_df
# Out:
#                                                   Names  \
# 0     Sunflower, Mexican Sunflower (Tithonia rotundi...
# 1                  Sunflower, Procut Horizon Pollenless
# 2                               Sunflower, Procut Peach
# 3        Sunflower, Procut Red Lemon BiColor Pollenless
# 4                    Sunflower, Autumn Beauty (90 days)
# ...                                                 ...
# 9155                 Endless Bouquets Cut Flower Garden
# 9156              Flower Power For Nature's Pollinators
# 9157  Heirloom Rainbow Flowers Colorful, Carefree Zi...
# 9158  Heirloom Summer Garden Dancing, Joyous Sunflowers
# 9159         Protect & Fertilize Green Cover Crop Blend
#
#                                             Description  \
# 0     \n\t\t\t\t\n\tDescription\n\nMexican Sunflower...
# 1     \n\t\t\t\t\n\tDescription\n\nA brand new ProCu...
# 2     \n\t\t\t\t\n\tDescription\n\nStunning, Peach-c...
# 3     \n\t\t\t\t\n\tDescription\n\nBicolor flowers o...
# ...

# %%
combined_df.to_csv("final.csv", index=False)

# %%
final
# Out:
#                                                   Names  \
# 0     Sunflower, Mexican Sunflower (Tithonia rotundi...
# 1                  Sunflower, Procut Horizon Pollenless
# 2                               Sunflower, Procut Peach
# 3        Sunflower, Procut Red Lemon BiColor Pollenless
# 4                    Sunflower, Autumn Beauty (90 days)
# ...                                                 ...
# 9155                 Endless Bouquets Cut Flower Garden
# 9156              Flower Power For Nature's Pollinators
# 9157  Heirloom Rainbow Flowers Colorful, Carefree Zi...
# 9158  Heirloom Summer Garden Dancing, Joyous Sunflowers
# 9159         Protect & Fertilize Green Cover Crop Blend
#
#                                             Description  \
# 0     \n\t\t\t\t\n\tDescription\n\nMexican Sunflower...
# 1     \n\t\t\t\t\n\tDescription\n\nA brand new ProCu...
# 2     \n\t\t\t\t\n\tDescription\n\nStunning, Peach-c...
# 3     \n\t\t\t\t\n\tDescription\n\nBicolor flowers o...
# ...
